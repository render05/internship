# %%
l =[10,20,30]
print(l,type(l))
print(l[1])
l2= ["a",23,"d"]
print (l2[0::2],type(l2))
print(len(l2))
# Out:
# [10, 20, 30] <class 'list'>
# 20
# ['a', 'd'] <class 'list'>
# 3

# %%
for i in range(4):
    print (i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(2):
    print(l[i]*2)
# Out:
# 20
# 40

# %%
for x in l2:
    print(x)
# Out:
# a
# 23
# d

# %%
s=0
for x in l:
    s+= x
    print(s)
# Out:
# 10
# 30
# 60
# 100

# %%
max = l[0]
for x in l:
    if x > max:
        max =x
        print(max)
# Out:
# 20
# 30
# 40

# %%
x=input("enter")
l =x.split()
print(l)
# Out:
# ['fg', 'hg', 'ghmn', 'hm']

# %%
l.append(20)
print(l)
# Out:
# ['fg', 'hg', 'ghmn', 'hm', 20, 20]

# %%
l.append(l2)
print(l)
# Out:
# ['fg', 'hg', 'ghmn', 'hm', 20, 20, ['a', 23, 'd'], ['a', 23, 'd']]

# %%
print(l[3],[2])
# Out:
# hm [2]

# %%
l.insert(3,"de")
print(l)
# Out:
# ['fg', 'hg', 'ghmn', 'de', 'de', ['a', 23, 'd'], 'hm', 20, 20, ['a', 23, 'd'], ['a', 23, 'd']]

# %%
l=[1,2,2,3,]
l.extend(l2)
print(l)
# Out:
# [1, 2, 2, 3, 'a', 23, 'd']

# %%
l.remove(20)
print(l)
# Out:
# ['fg', 'hg', 'ghmn', 'de', 'de', ['a', 23, 'd'], 'hm', 20, ['a', 23, 'd'], ['a', 23, 'd'], ['a', 23, 'd'], 'a', 23, 'd']

# %%
l=[1,2,3,4]
l.pop()
print(l)
# Out:
# [1, 2, 3]

# %%
Sum=sum(l)
print(Sum)
Sum=sum(l,10)
print(Sum)
# Out:
# 6
# 16

# %%
l=[13,23,34]
while(True):
    print("""
          1.Add element
          2. Remove Element
          3.Display first three element 
          4.display last three element
          5.print
          6.exit""")
    ch =int(input("enter your choice:"))
    if ch ==1:
       e=input("eneter an elemnrt")
       l.append(e)
       
    elif ch == 2:
     if l.count() ==0:
        print("list is empty")
     else:
        l.pop(0)
    
    elif ch == 3:
        if l.count() ==3:
           print(l)
        else:
           print("less no")
    elif ch == 4:
        pass
    elif ch == 5:
        pass
    elif ch == 6:
         pass
else:
    print("error")
         break
# Out:
#   Cell In[63], line 34
#     break
#     ^
# IndentationError: unexpected indent
