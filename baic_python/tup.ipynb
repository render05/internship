# %%
l =[1,2,3,4]
d={2:"abc"}
t=(12,23,34,43,56,55)
print(t,type(t))
# Out:
# (12, 23, 34, 43, 56, 55) <class 'tuple'>

# %%
print(t[1])
# Out:
# 23

# %%
for i in t:
    print(i)
# Out:
# 12
# 23
# 34
# 43
# 56
# 55

# %%
l =[1,2,3,4]
d={2:"abc"}
t=(12,23,34,43,56,55,{1:"pkc"})
print(t,type(t))
print(t[6][1])
# Out:
# (12, 23, 34, 43, 56, 55, {1: 'pkc'}) <class 'tuple'>
# pkc

# %%
t1=(1,23,4,3)
t2=('a','d','d')
print(t1+t2)
# Out:
# (1, 23, 4, 3, 'a', 'd', 'd')

# %%
t2=('xys')*6
print(t2)
# Out:
# xysxysxysxysxysxys

# %%
t1=(91,2,3,4)
t2=(23,323,12,43)
print(t2[1:2])
# Out:
# (323,)

# %%
t1=[1,23,4,5]
t1=tuple(t1)
print(t1,type(t1))
# Out:
# (1, 23, 4, 5) <class 'tuple'>

# %%
print(min(t1))
print(max(t1))
print(t.count(4))
print(t.index(23))
print(sum(t1))
# Out:
# 1
# 23
# 0
# 1
# 33
