# %%
import csv
d= [
    ["name","email","mobile"],
    ["abd","dhbsgshg","78987899"],
    ["sbd","dhbsgshg","789878999"],
    ["adcbd","d56bsgshg","785687899"],
    ["acbd","dhbsgshg","789845899"],
]
with open("data.csv","w",newline ="")as file:
    writer = csv.writer(file)
    for  row  in d:
        writer.writerow(row)

# %%
import csv
d= [
    ["name","email","mobile"],
    ["abd","dhbsgshg","78987899"],
    ["sbd","dhbsgshg","789878999"],
    ["adcbd","d56bsgshg","785687899"],
    ["acbd","dhbsgshg","789845899"],
]
with open("data.csv","a",newline ="")as file:
    writer = csv.writer(file)
    for  row  in d:
        writer.writerow(row)

# %%
with open("data.csv","r",newline ="")as file:
    reader = csv.reader(file)
    for  row  in reader:
       print(row)
# Out:
# ['name', 'email', 'mobile']
# ['abd', 'dhbsgshg', '78987899']
# ['sbd', 'dhbsgshg', '789878999']
# ['adcbd', 'd56bsgshg', '785687899']
# ['acbd', 'dhbsgshg', '789845899']
# ['name', 'email', 'mobile']
# ['abd', 'dhbsgshg', '78987899']
# ['sbd', 'dhbsgshg', '789878999']
# ['adcbd', 'd56bsgshg', '785687899']
# ['acbd', 'dhbsgshg', '789845899']

# %%
try:
    n1=int (input("enter a divisor"))
    res =36/n1
    print(res)#exception
except ZeroDivisionError:
    print("print by division error")
except ValueError:
    print("invalid value")
# Out:
# 0.8

# %%
try:
    n1=(91,2,3,4)
    print(n1[5])
except IndexError:
    print("inder error hai")
# Out:
# inder error hai
