# %%
d = {1:"python",2:"Java",3:"React"}
print(d, type(d))
# Out:
# {1: 'python', 2: 'Java', 3: 'React'} <class 'dict'>

# %%
print(d[1])
# Out:
# python

# %%
d = {'1':"python",'2':"Java",'3':"React"}
print(d['1'])
# Out:
# python

# %%
d = {1:"python",2:"Java",3:{'pname':"abc","mrp":480}}
print(d[3]['pname'])
# Out:
# abc

# %%
d ={}
d[0]= "A"
print(d)
# Out:
# {0: 'A'}

# %%
d ={}
d[0]= "A"
d['alpha']="A"
d['alpha']="b"
d['alpha']="c"
print(d)

# %%
d = {'1':"python",'2':"Java",'3':"React"}
d2 = d.copy()
print(d)
print(d2.values())
print(d2.items())
print(d2.keys())
d2.update({5:"monday"})
print(d2)
# Out:
# {'1': 'python', '2': 'Java', '3': 'React'}
# dict_values(['python', 'Java', 'React'])
# dict_items([('1', 'python'), ('2', 'Java'), ('3', 'React')])
# dict_keys(['1', '2', '3'])
# {'1': 'python', '2': 'Java', '3': 'React', 5: 'monday'}

# %%
d2.update(d3)
print(d3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d2.update(d3)
#       2 print(d3)
#
# NameError: name 'd3' is not defined
