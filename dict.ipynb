# %%
d = {1:"python",2:"Java",3:"React"}
print(d, type(d))
# Out:
# {1: 'python', 2: 'Java', 3: 'React'} <class 'dict'>

# %%
print(d[1])
# Out:
# python

# %%
d = {'1':"python",'2':"Java",'3':"React"}
print(d['1'])
# Out:
# python

# %%
d = {1:"python",2:"Java",3:{'pname':"abc","mrp":480}}
print(d[3]['pname'])
# Out:
# abc

# %%
d ={}
d[0]= "A"
print(d)
# Out:
# {0: 'A'}

# %%
d ={}
d[0]= "A"
d['alpha']="A"
d['alpha']="b"
d['alpha']="c"
print(d)
