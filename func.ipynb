# %%
def function(n1,n2):
    print(n1*n2)


function(20,30)
# Out:
# 600

# %%
def function(n1,n2):
    print(n1*n2)


function(20,30)
function(20,30)
function(20,30)
function(20,30)
# Out:
# 600
# 600
# 600
# 600

# %%
def fun(*city):
    print(city[1])
fun("jaipur","delhi","fun")
# Out:
# delhi

# %%
def fun(city1,city2,city3):
    print(city2)
fun(city2="jaipur",city1="delhi",city3="fun")
# Out:
# jaipur

# %%
def fun(**city):
    print(city)
fun(city2="jaipur",city1="delhi",city3="fun")
# Out:
# {'city2': 'jaipur', 'city1': 'delhi', 'city3': 'fun'}

# %%
def fun(country="india"):
    print("i am fom"+ country)
fun()
# Out:
# i am fomindia

# %%
def fun(fruit):
    for x in fruit:
        print(x)#iteration
fruits = ["apple","banan","cherry"] 
fun(fruits)
# Out:
# apple
# banan
# cherry

# %%
def fun(x):
    return 5*x
fun(10)
print(fun(23))
# Out:
# 115

# %%
def function(n1,/):
    print(n1*2)


function(5)
# Out:
# 10

# %%
def function(*,n1):
    print(n1*2)


function(n1=5)#after * are keywoeds so use n1=5 not direct 5
# Out:
# 10

# %%
def fun(a,s,/,*,c,d):
    print(a+s+c+d)
fun(5,6,c=4,d=3)
# Out:
# 18

# %%
def recursion(k):
    if k>0:
        print(k)
        k =k-1
        recursion(k)
    else:
        print(k)
recursion(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
